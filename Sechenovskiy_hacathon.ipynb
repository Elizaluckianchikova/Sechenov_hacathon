# %% [markdown]
# <a href="https://colab.research.google.com/github/Elizaluckianchikova/Sechenov_hacathon/blob/main/Sechenovskiy_hacathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install matplotlib-venn

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-0d33fc52-95e3-4023-b8aa-213c54c03ae6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0d33fc52-95e3-4023-b8aa-213c54c03ae6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv('clusters_metric_human_brain.csv')
#type(df)
#df1
#df1.columns
#colors=df['colors']
#colors
#cluster= df['cluster']
#cluster
#quantaty_gene = df['quantaty_gene']
#quantaty_gene
#difference=df['difference']
#difference
df1
# Out:
#      Unnamed: 0      cluster     n  difference
# 0         black        black    26   -0.277778
# 1          blue         blue    47   -0.729885
# 2         brown        brown    87   -0.511236
# 3          cyan         cyan    92   -0.402597
# 4         green        green    20    0.000000
# 5   greenyellow  greenyellow    14    0.000000
# 6       magenta      magenta    20   -0.285714
# 7          pink         pink    36   -0.076923
# 8        purple       purple    95   -0.362416
# 9           red          red   506   -0.385922
# 10       salmon       salmon  4045   -0.416222
# 11          tan          tan    17   -0.291667
# 12    turquoise    turquoise    55   -0.035088
# 13       yellow       yellow   107   -0.157480
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# ...

# %%
from matplotlib import pyplot as plt
df1.plot(kind='scatter', x='n', y='difference', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
df1['difference'].plot(kind='line', figsize=(8, 4), title='difference')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
df1['n'].plot(kind='line', figsize=(8, 4), title='n')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
df1['difference'].plot(kind='hist', bins=20, title='difference')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
import pandas as pd
import numpy as np
df2 = pd.read_csv('gene_modules_human_brain.csv')
#type(df)
#df1
#df1.columns
#index= df["index"]
#index
#gene_id=df['gene_id']
#gene_id
#colors=df['colors']
#colors
#difference=df['difference']
#difference
df2
# Out:
#        Unnamed: 0   gene_id     colors
# 0               1      A1BG     salmon
# 1               2  A1BG-AS1     salmon
# 2               3       A2M  turquoise
# 3               4   A2M-AS1     salmon
# 4               5      AAAS     salmon
# ...           ...       ...        ...
# 10354       10355      ZXDB     salmon
# 10355       10356      ZXDC     salmon
# 10356       10357    ZYG11B     salmon
# 10357       10358       ZYX     salmon
# 10358       10359     ZZEF1     salmon
#
# [10359 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df2['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
from google.colab import data_table
data_table.DataTable(df2(), colors=['turquoise'], index=[100...] )
# Out:
#   File "<ipython-input-29-01a56f22589b>", line 2
#     data_table.DataTable(df2(), colors=['turquoise'], index=[100...] )
#                                                                   ^
# SyntaxError: invalid syntax

# %%
from matplotlib import pyplot as plt
df2['Unnamed: 0'].plot(kind='line', figsize=(8, 4), title='Unnamed: 0')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# import modules
from matplotlib_venn import venn2
from matplotlib import pyplot as plt

# depict venn diagram
venn2(subsets = (50, 10, 7), set_labels = ('Group A', 'Group B'))
plt.show()
